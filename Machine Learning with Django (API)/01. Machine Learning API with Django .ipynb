# %%
# Import Library
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler
import warnings
from collections import Counter
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
from keras import Sequential
from keras.layers  import Dense

# %%
df = pd.read_csv('bankloan.csv')
df=df.dropna()
df.isna().any()
df = df.drop('Loan ID', axis=1)
df['Current Loan Amount']=(df['Current Loan Amount']*1000).astype(int)
Counter(df['Loan Status'])
# Out:
# Counter({'Fully Paid': 28972, 'Charged Off': 7451})

# %%
pre_y = df['Loan Status']
pre_x = df.drop('Loan Status', axis=1)
dm_x = pd.get_dummies(pre_x)
dm_y = pre_y.map(dict(Y=1, N=0))
pre_x
# Out:
#                                 Customer ID  Current Loan Amount        Term  \
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725          99999999000  Short Term
# 6      90a75dde-34d5-419c-90dc-1e58b04b3e35            217646000  Short Term
# 8      af534dea-d27e-4fd6-9de8-efaa52a78ec0            548746000  Short Term
# 10     0de7bcdb-ebf4-4608-ba39-05f083f855b6          99999999000  Short Term
# 12     11581f68-de3c-49d8-80d9-22268ebb323b          99999999000  Short Term
# ...                                     ...                  ...         ...
# 99990  1a583add-21ba-410f-9c42-757c4ed19322          99999999000  Short Term
# 99993  e45e8dc4-05ad-4efe-92cc-784a6d5ef61a             44484000  Short Term
# 99994  be67200e-1ef1-4b63-86a6-2bf27d3c704d            210584000  Short Term
# 99996  77f2252a-b7d1-4b07-a746-1202a8304290          99999999000  Short Term
# 99997  2ced5f10-bd60-4a11-9134-cadce4e7b0a3            103136000  Short Term
#
#        Credit Score  Annual Income Years in current job Home Ownership  \
# 2             741.0      2231892.0              8 years       Own Home
# 6             730.0      1184194.0             < 1 year  Home Mortgage
# 8             678.0      2559110.0              2 years           Rent
# 10            728.0       714628.0              3 years           Rent
# 12            740.0       776188.0             < 1 year       Own Home
# ...             ...            ...                  ...            ...
# 99990         742.0      1190046.0             < 1 year           Rent
# 99993         717.0      1152426.0            10+ years  Home Mortgage
# 99994         719.0       783389.0               1 year  Home Mortgage
# 99996         732.0      1289416.0               1 year           Rent
# 99997         742.0      1150545.0              6 years           Rent
#
#                   Purpose  Monthly Debt  Years of Credit History  \
# 2      Debt Consolidation      29200.53                     14.9
# 6      Debt Consolidation      10855.08                     19.6
# 8      Debt Consolidation      18660.28                     22.6
# 10     Debt Consolidation      11851.06                     16.0
# 12     Debt Consolidation      11578.22                      8.5
# ...                   ...           ...                      ...
# 99990               other      11969.81                     20.1
# 99993      small_business       6280.64                     21.0
# 99994               Other       3727.61                     17.4
# 99996  Debt Consolidation      13109.05                      9.4
# 99997  Debt Consolidation       7315.57                     18.8
#
#        Months since last delinquent  Number of Open Accounts  \
# 2                              29.0                       18
# 6                              10.0                       13
# 8                              33.0                        4
# 10                             76.0                       16
# 12                             25.0                        6
# ...                             ...                      ...
# 99990                          16.0                        9
# 99993                          12.0                        6
# 99994                          18.0                        6
# 99996                          21.0                       22
# 99997                          18.0                       12
#
#        Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 2                              1                  297996             750090.0
# 6                              1                  122170             272052.0
# 8                              0                  437171             555038.0
# 10                             0                  203965             289784.0
# 12                             0                  134083             220220.0
# ...                          ...                     ...                  ...
# 99990                          0                   37392             134442.0
# 99993                          0                  961932                  0.0
# 99994                          0                     456             259160.0
# 99996                          0                  153045             509234.0
# 99997                          1                  109554             537548.0
#
#        Bankruptcies  Tax Liens
# 2               0.0        0.0
# 6               1.0        0.0
# 8               0.0        0.0
# 10              0.0        0.0
# 12              0.0        0.0
# ...             ...        ...
# 99990           0.0        0.0
# 99993           0.0        0.0
# 99994           0.0        0.0
# 99996           0.0        0.0
# 99997           1.0        0.0
#
# [36423 rows x 17 columns]
