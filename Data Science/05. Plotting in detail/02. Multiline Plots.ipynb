# %% [markdown]
# # Multiline Plots

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt 

x = np.arange(10)
plt.plot(x, x**2)
plt.plot(x, x**3)
plt.plot(x, x*3)
plt.plot(x, 2**x)
plt.show()

# %%
plt.plot(x, x**2, x, x**3, x, x*3, x, 2**x)
plt.show()

# %%
x = np.array([[1, 2, 6, 3], [4, 5, 3, 2]])
plt.plot(x)
plt.show()

# %%
data = np.random.randn(2, 10)
print(data)
plt.plot(data[0], data[1])
plt.show()
# Out:
# [[-1.22578921 -0.03401819 -0.52930736  2.02692218 -0.0335457  -2.30575319
#    1.39828528 -0.24710228 -0.21570109  0.44406501]
#  [ 0.59977164  0.82561084 -0.8551873   0.5389753   2.32320302 -1.04243602
#    0.41356714  0.09155327  0.42324488  1.14505416]]
